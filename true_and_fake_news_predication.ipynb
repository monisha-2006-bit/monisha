# %% [markdown]
# <a href="https://colab.research.google.com/github/monisha-2006-bit/monisha/blob/main/true_and_fake_news_predication.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
#import the required libraries for the analysis of the project

# %%
from google.colab import drive
drive.mount('/content/drive')
#mounting of drive
# Out:
# Mounted at /content/drive

# %%
train=pd.read_csv('/content/drive/MyDrive/True and Fake News Prediction/train.csv')
# Read the 'Train.csv' file into a pandas DataFrame called 'train'

# %%
test=pd.read_csv('/content/drive/MyDrive/True and Fake News Prediction/test.csv')
# Read the 'TEST.csv' file into a pandas DataFrame called 'train'

# %%
train.shape
#The function.shape returns the number of rows and columns present in the given dataset.
# Out:
# (20800, 5)

# %%
test.shape
#The function.shape returns the number of rows and columns present in the given dataset.
# Out:
# (5200, 4)

# %%
train.info()
#The function.info() prints the information about the dataframe.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20800 entries, 0 to 20799
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      20800 non-null  int64
#  1   title   20242 non-null  object
#  2   author  18843 non-null  object
#  3   text    20761 non-null  object
#  4   label   20800 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 812.6+ KB

# %%
test.info()
#The function.info() prints the information about the dataframe.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5200 entries, 0 to 5199
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      5200 non-null   int64
#  1   title   5078 non-null   object
#  2   author  4697 non-null   object
#  3   text    5193 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 162.6+ KB

# %%
train.isnull().sum()
#the function.dtypes retuns the data type of eachcoloumns of the dataframe.
# Out:
# id           0
# title      558
# author    1957
# text        39
# label        0
# dtype: int64

# %%
test.isnull().sum()
#the function.dtypes retuns the data type of eachcoloumns of the dataframe.
# Out:
# id          0
# title     122
# author    503
# text        7
# dtype: int64

# %%
train.describe()
#The function.describe() returns the description of the data in the dataframe.
# Out:
#                  id         label
# count  20800.000000  20800.000000
# mean   10399.500000      0.500625
# std     6004.587135      0.500012
# min        0.000000      0.000000
# 25%     5199.750000      0.000000
# 50%    10399.500000      1.000000
# 75%    15599.250000      1.000000
# max    20799.000000      1.000000

# %%
test.describe()
#The function.describe() returns the description of the data in the dataframe.
# Out:
#                  id
# count   5200.000000
# mean   23399.500000
# std     1501.255031
# min    20800.000000
# 25%    22099.750000
# 50%    23399.500000
# 75%    24699.250000
# max    25999.000000

# %%
train.head()
#The function.head() returns the spcify number of rows,string on the dataset.
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1

# %%
test.head()
#The function.head() returns the spcify number of rows,string on the dataset.
# Out:
#       id                                              title  \
# 0  20800  Specter of Trump Loosens Tongues, if Not Purse...
# 1  20801  Russian warships ready to strike terrorists ne...
# 2  20802  #NoDAPL: Native American Leaders Vow to Stay A...
# 3  20803  Tim Tebow Will Attempt Another Comeback, This ...
# 4  20804                    Keiser Report: Meme Wars (E995)
#
#                     author                                               text
# 0         David Streitfeld  PALO ALTO, Calif.  —   After years of scorning...
# 1                      NaN  Russian warships ready to strike terrorists ne...
# 2            Common Dreams  Videos #NoDAPL: Native American Leaders Vow to...
# 3            Daniel Victor  If at first you don’t succeed, try a different...
# 4  Truth Broadcast Network  42 mins ago 1 Views 0 Comments 0 Likes 'For th...

# %% [markdown]
# #Data Preprocessing

# %% [markdown]
# 1.Removing null values

# %%
train=train.fillna('')
#replaces the NULL values with a specified value.

# %%
train.isnull().sum()
#The function.isnull().sum() returns the number of missing values in the dataset.
# Out:
# id        0
# title     0
# author    0
# text      0
# label     0
# dtype: int64

# %%
train.describe()
#The function.describe() returns the description of the data in the dataframe.
# Out:
#                  id         label
# count  20800.000000  20800.000000
# mean   10399.500000      0.500625
# std     6004.587135      0.500012
# min        0.000000      0.000000
# 25%     5199.750000      0.000000
# 50%    10399.500000      1.000000
# 75%    15599.250000      1.000000
# max    20799.000000      1.000000

# %%
train['subject']=train['author'] + '' + train['title']
#for splitting into two sections.

# %%
test=test.fillna('')
#replaces the NULL values with a specified value.

# %%
test.isnull().sum()
#The function.isnull().sum() returns the number of missing values in the dataset..
# Out:
# id        0
# title     0
# author    0
# text      0
# dtype: int64

# %%
train.describe()
#The function.describe() returns the description of the data in the dataframe.
# Out:
#                  id         label
# count  20800.000000  20800.000000
# mean   10399.500000      0.500625
# std     6004.587135      0.500012
# min        0.000000      0.000000
# 25%     5199.750000      0.000000
# 50%    10399.500000      1.000000
# 75%    15599.250000      1.000000
# max    20799.000000      1.000000

# %%
test['subject']=test['author'] + '' + test['title']
#for splitting into two sections.

# %% [markdown]
# 2.Tokenization

# %%
import nltk
nltk.download('punkt')
#splits a given sentence into words using the NLTK library.
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.tokenize import word_tokenize
test['tokens']=test['subject'].apply(word_tokenize)
#splits a given sentence into words using the N

# %%
test.head()
#The function.head() returns the spcify number of rows,string on the dataset.
# Out:
#       id                                              title  \
# 0  20800  Specter of Trump Loosens Tongues, if Not Purse...
# 1  20801  Russian warships ready to strike terrorists ne...
# 2  20802  #NoDAPL: Native American Leaders Vow to Stay A...
# 3  20803  Tim Tebow Will Attempt Another Comeback, This ...
# 4  20804                    Keiser Report: Meme Wars (E995)
#
#                     author                                               text  \
# 0         David Streitfeld  PALO ALTO, Calif.  —   After years of scorning...
# 1                           Russian warships ready to strike terrorists ne...
# 2            Common Dreams  Videos #NoDAPL: Native American Leaders Vow to...
# 3            Daniel Victor  If at first you don’t succeed, try a different...
# 4  Truth Broadcast Network  42 mins ago 1 Views 0 Comments 0 Likes 'For th...
#
#                                              subject  \
# 0  David StreitfeldSpecter of Trump Loosens Tongu...
# ...

# %%
from nltk.tokenize import word_tokenize
train['tokens']=train['subject'].apply(word_tokenize)
#splits a given sentence into words using the NLTK library.

# %%
train.head()
#The function.head() returns the spcify number of rows,string on the dataset.
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1
#
#                                              subject  \
# 0  Darrell LucusHouse Dem Aide: We Didn’t Even Se...
# ...

# %% [markdown]
# LOWER CASING FOR TEST

# %%
train['subject']= train['subject'].str.lower()
#The . lower() method takes no arguments and returns the lowercased strings from the given string by converting each uppercase character to lowercase.

# %%
train.head()
#The function.head() returns the spcify number of rows,string on the dataset.
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1
#
#                                              subject  \
# 0  darrell lucushouse dem aide: we didn’t even se...
# ...

# %%
test['subject']= test['subject'].str.lower()
#The . lower() method takes no arguments and returns the lowercased strings from the given string by converting each uppercase character to lowercase.

# %%
test.head()
#The function.head() returns the spcify number of rows,string on the dataset.
# Out:
#       id                                              title  \
# 0  20800  Specter of Trump Loosens Tongues, if Not Purse...
# 1  20801  Russian warships ready to strike terrorists ne...
# 2  20802  #NoDAPL: Native American Leaders Vow to Stay A...
# 3  20803  Tim Tebow Will Attempt Another Comeback, This ...
# 4  20804                    Keiser Report: Meme Wars (E995)
#
#                     author                                               text  \
# 0         David Streitfeld  PALO ALTO, Calif.  —   After years of scorning...
# 1                           Russian warships ready to strike terrorists ne...
# 2            Common Dreams  Videos #NoDAPL: Native American Leaders Vow to...
# 3            Daniel Victor  If at first you don’t succeed, try a different...
# 4  Truth Broadcast Network  42 mins ago 1 Views 0 Comments 0 Likes 'For th...
#
#                                              subject  \
# 0  david streitfeldspecter of trump loosens tongu...
# ...

# %% [markdown]
# REMOVAL OF PUNCTUATION

# %%
train['subject']=train['subject'].str.replace('[^\w\s]','')

# %%
train.head()
#The function.head() returns the spcify number of rows,string on the dataset.
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1
#
#                                              subject  \
# 0  darrell lucushouse dem aide: we didn’t even se...
# ...

# %%
test['subject']=test['subject'].str.replace('[^\w\s]','')

# %%
test.head()
#The function.head() returns the spcify number of rows,string on the dataset.
# Out:
#       id                                              title  \
# 0  20800  Specter of Trump Loosens Tongues, if Not Purse...
# 1  20801  Russian warships ready to strike terrorists ne...
# 2  20802  #NoDAPL: Native American Leaders Vow to Stay A...
# 3  20803  Tim Tebow Will Attempt Another Comeback, This ...
# 4  20804                    Keiser Report: Meme Wars (E995)
#
#                     author                                               text  \
# 0         David Streitfeld  PALO ALTO, Calif.  —   After years of scorning...
# 1                           Russian warships ready to strike terrorists ne...
# 2            Common Dreams  Videos #NoDAPL: Native American Leaders Vow to...
# 3            Daniel Victor  If at first you don’t succeed, try a different...
# 4  Truth Broadcast Network  42 mins ago 1 Views 0 Comments 0 Likes 'For th...
#
#                                              subject  \
# 0  david streitfeldspecter of trump loosens tongu...
# ...

# %% [markdown]
# REMOVAL OF STOPWORDS

# %%
nltk.download('stopwords')
# Downloading the stopwords that are present in English Langugae
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
sw=set(nltk.corpus.stopwords.words('english'))
print(sw)
# Showcasing the stopwords in English
# Out:
# {'during', 'yourself', 'but', 'at', "couldn't", 'some', 'from', "weren't", 'them', 'being', 'does', 'how', 'don', 'ourselves', 'him', 'himself', 'most', 'having', 'didn', 'am', 'to', "shouldn't", 'hasn', 'for', 'with', "it's", 'on', 'm', 'and', 'why', 'it', 've', 'are', 'o', 'your', 'now', 'if', 'about', "didn't", 'our', 'been', 'any', 'shouldn', 'd', 'this', 'her', 'themselves', 'its', 'these', 'further', 'between', 'couldn', "shan't", 'you', 'their', 'of', 'before', 'ain', 'under', "isn't", 'itself', 'such', 'the', 'both', 'mustn', 'very', 'above', 'few', 'same', 'until', 'have', 'will', "mustn't", 'who', "you'll", 'hers', 'doesn', 'shan', 'doing', 'down', "you've", "that'll", 'own', 'can', "won't", 'i', 'just', 'myself', "wasn't", 'out', 'that', 'then', "hadn't", 'y', 'again', 'weren', 'll', "haven't", 'where', 'they', 'over', "should've", 'herself', 'when', 'he', 'up', 'isn', 'in', 'won', 's', 're', 'has', "doesn't", 'his', 'is', 'once', 'below', 'off', 'each', 'my', 'through', '
# ...

# %%
train['subject'] = train['subject'].apply(lambda x: ' '.join([word for word in x.split() if word not in sw]))
# Here we try to remove the stopwords by adding only the words which are not in the SW stopword set.

# %%
train.head()
#The function.head() returns the spcify number of rows,string on the dataset.
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1
#
#                                              subject  \
# 0  darrell lucushouse dem aide: didn’t even see c...
# ...

# %%
test['subject'] = test['subject'].apply(lambda x: ' '.join([word for word in x.split() if word not in sw]))
# Here we try to remove the stopwords by adding only the words which are not in the SW stopword set.

# %%
test.head()
#The function.head() returns the spcify number of rows,string on the dataset.
# Out:
#       id                                              title  \
# 0  20800  Specter of Trump Loosens Tongues, if Not Purse...
# 1  20801  Russian warships ready to strike terrorists ne...
# 2  20802  #NoDAPL: Native American Leaders Vow to Stay A...
# 3  20803  Tim Tebow Will Attempt Another Comeback, This ...
# 4  20804                    Keiser Report: Meme Wars (E995)
#
#                     author                                               text  \
# 0         David Streitfeld  PALO ALTO, Calif.  —   After years of scorning...
# 1                           Russian warships ready to strike terrorists ne...
# 2            Common Dreams  Videos #NoDAPL: Native American Leaders Vow to...
# 3            Daniel Victor  If at first you don’t succeed, try a different...
# 4  Truth Broadcast Network  42 mins ago 1 Views 0 Comments 0 Likes 'For th...
#
#                                              subject  \
# 0  david streitfeldspecter trump loosens tongues,...
# ...

# %% [markdown]
# STEMMING OR LIMITISATION

# %%
from nltk.stem import PorterStemmer
#imports the PorterStemmer module from the NLTK library.

# %%
# To apply Stemming or Lemmatization :
stemmer = PorterStemmer()
train['subject'] = train['subject'].apply(lambda x: ' '.join([stemmer.stem(word) for word in x.split()]))
# Stemming is the simple process of reducing the words to their root forms

# %%
# To apply Stemming or Lemmatization :
stemmer = PorterStemmer()
train['subject'] = train['subject'].apply(lambda x: ' '.join([stemmer.stem(word) for word in x.split()]))
# Stemming is the simple process of reducing the words to their root

# %%
# To apply Stemming or Lemmatization :
stemmer = PorterStemmer()
test['subject'] = test['subject'].apply(lambda x: ' '.join([stemmer.stem(word) for word in x.split()]))
# Stemming is the simple process of reducing the words to their root forms

# %%
test.head()
#The function.head() returns the spcify number of rows,string on the dataset.
# Out:
#       id                                              title  \
# 0  20800  Specter of Trump Loosens Tongues, if Not Purse...
# 1  20801  Russian warships ready to strike terrorists ne...
# 2  20802  #NoDAPL: Native American Leaders Vow to Stay A...
# 3  20803  Tim Tebow Will Attempt Another Comeback, This ...
# 4  20804                    Keiser Report: Meme Wars (E995)
#
#                     author                                               text  \
# 0         David Streitfeld  PALO ALTO, Calif.  —   After years of scorning...
# 1                           Russian warships ready to strike terrorists ne...
# 2            Common Dreams  Videos #NoDAPL: Native American Leaders Vow to...
# 3            Daniel Victor  If at first you don’t succeed, try a different...
# 4  Truth Broadcast Network  42 mins ago 1 Views 0 Comments 0 Likes 'For th...
#
#                                              subject  \
# 0  david streitfeldspect trump loosen tongues, pu...
# ...

# %% [markdown]
# VECTORISTION

# %%
x=train['subject']
y=train['label']
#The training part of the second array.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
#import the required library for the analysis of the project

# %%
Vt=TfidfVectorizer()
Vt.fit(x)
##to convert a collection of raw documents to a matrix of TF-IDF features.
# Out:
# TfidfVectorizer()

# %%
x.head()
# Display the first five rows of the 'train' Dataframe.
# Out:
# 0    darrel lucush dem aide: didn’t even see comey’...
# 1    daniel j. flynnflynn: hillari clinton, big wom...
# 2           consortiumnews.comwhi truth might get fire
# 3    jessica purkiss15 civilian kill singl us airst...
# 4    howard portnoyiranian woman jail fiction unpub...
# Name: subject, dtype: object

# %%
x=Vt.transform(x)
#modifying datas with functions.

# %%
print(x)
#display the 'x'.
# Out:
#   (0, 29901)	0.2702317405535354
#   (0, 25855)	0.23633175774140575
#   (0, 17230)	0.39616172821890755
#   (0, 16719)	0.2687730240968852
#   (0, 14816)	0.2267902704938032
#   (0, 9470)	0.2131010345817379
#   (0, 7746)	0.2725285388588018
#   (0, 7449)	0.26535031144709154
#   (0, 7108)	0.3269077189450684
#   (0, 5977)	0.22776883917952795
#   (0, 5107)	0.3339547020931297
#   (0, 1086)	0.36074580999296135
#   (1, 31745)	0.3697872989088357
#   (1, 13131)	0.25285168767185423
#   (1, 10359)	0.5268164226435469
#   (1, 7049)	0.31888871084479553
#   (1, 5713)	0.23432931603021007
#   (1, 4710)	0.450403390641861
#   (1, 4060)	0.1868623738195069
#   (1, 3336)	0.3569409406802066
#   (2, 29789)	0.36635739112785753
#   (2, 18680)	0.4315491786494108
#   (2, 11135)	0.3064339824029749
#   (2, 10133)	0.3472323577842834
#   (2, 6274)	0.404084133229652
#   :	:
#   (20797, 28725)	0.31682936981975635
#   (20797, 25155)	0.24858739168568383
#   (20797, 23680)	0.2724797898018777
# ...

# %%
# For building the machine learning models
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
# For evaluating the models using the metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.model_selection  import cross_val_score as CVS
from sklearn.metrics import classification_report

# %%
xTrain,xTest,yTrain,yTest=train_test_split(x,y,test_size=0.2,stratify=y,random_state=42)
#the training part and the testing part of the first and second array.

# %%
Modal=LogisticRegression()
#aims to solve classification problems.

# %%
Modal.fit(xTrain,yTrain)
#fit training data
# Out:
# LogisticRegression()

# %%
ytrpredict=Modal.predict(xTrain)
# generate predictions from a trained neural network model.

# %%
accuracy =accuracy_score(yTrain,ytrpredict)
precision = precision_score(yTrain, ytrpredict)
recall = recall_score(yTrain, ytrpredict)
f1 = f1_score(yTrain, ytrpredict)

print(' Training Accuracy:', accuracy)
print(' Training Precision:', precision)
print(' Training Recall:', recall)
print('Training F1 Score:', f1)
# Out:
#  Training Accuracy: 0.9719951923076923
#  Training Precision: 0.952161913523459
#  Training Recall: 0.9939975990396158
# Training F1 Score: 0.9726300951485962

# %%
Yttpredict=Modal.predict(xTest)
# generate predictions from a tested neural network model.

# %%
accuracy  =accuracy_score(yTest,Yttpredict)
precision = precision_score(yTest, Yttpredict)
recall = recall_score(yTest, Yttpredict)
f1 = f1_score(yTest, Yttpredict)

print(' Testing Accuracy:', accuracy)
print(' Testing Precision:', precision)
print(' Testing Recall:', recall)
print('Testing F1 Score:', f1)
# Out:
#  Testing Accuracy: 0.9507211538461539
#  Testing Precision: 0.9184491978609626
#  Testing Recall: 0.9894383101296207
# Testing F1 Score: 0.9526230644788537

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
#import the required library for the analysis of the project.

# %%
# Generate the confusion matrix
cm = confusion_matrix(yTrain,ytrpredict)

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)

plt.show()

# %%
# Generate the confusion matrix
cm = confusion_matrix(yTest,Yttpredict)

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)

plt.show()

# %% [markdown]
# SUMMARY
#
# This project focuses on predicting the reliability of news articles by analyzing text features such as word patterns and sentiment using Natural Language Processing (NLP). The program’s data structure efficiently organizes news articles, storing features like text, labels (true/fake), and vectorized content, enabling precise content analysis.
#
# Data preprocessing is a critical phase in this project, involving several steps to prepare the raw data for machine learning. These steps include:
#
# Removing Null Values: Discarding incomplete or missing data to ensure dataset quality.
# 1.Tokenization: Splitting text into words or phrases for detailed analysis.
# 2.Lower Casing Text: Standardizing text by converting all characters to lowercase.
# 3.Removal of Punctuation: Simplifying text by stripping unnecessary punctuation.
# 4.Removal of Stop Words: Eliminating common, non-informative words.
# 5.Stemming or Lemmatization: Reducing words to their root forms for consistency.
# 6.Vectorization: Converting text into numerical data for model input.
# These preprocessing steps enhance data quality, enabling accurate true and fake news classification.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
